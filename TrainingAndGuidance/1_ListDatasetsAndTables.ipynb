# %%
#ListDatasetsAndTables
#Sample script to list accessible datasets
#and tables within a dataset

# %%
library(bigrquery)


bq_project_datasets('yhcr-prd-phm-bia-core', page_size = 50, max_pages = Inf)
# Out:
# [[1]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1112_Allsop
#
# [[2]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1242
#
# [[3]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1322
#
# [[4]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1341
#
# [[5]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1401_Elshehaly
#
# [[6]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1403_Martin
#
# [[7]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1551
#
# [[8]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1551_Best
#
# [[9]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1551_CB
#
# [[10]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1551_EfiProject
#
# [[11]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1561_BV
#
# [[12]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1561_Villa
#
# [[13]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1576_Frost
#
# [[14]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1645_Hussain
#
# [[15]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1646_Jones
#
# [[16]]
# <bq_dataset> yhcr-prd-phm-bia-core.CB_1659_Hou
#
# [[17]]
# ...

# %%
#List the tables in a dataset 

library(bigrquery)

tables = bq_dataset_tables('yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8')

tables
# Out:
# [[1]]
# <bq_table> yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8.care_site
#
# [[2]]
# <bq_table> yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8.cb_change_log
#
# [[3]]
# <bq_table> yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8.cb_srmedicationreadcodedetails
#
# [[4]]
# <bq_table> yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8.data_dictionary
#
# [[5]]
# <bq_table> yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8.observation_period
#
# [[6]]
# <bq_table> yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8.person
#
# [[7]]
# <bq_table> yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8.provider
#
# [[8]]
# <bq_table> yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8.tbl_srappointment
#
# [[9]]
# <bq_table> yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8.tbl_srcode
#
# [[10]]
# <bq_table> yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8.tbl_srconfiguredlistoption
#
# [[11]]
# <bq_table> yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8.tbl_srimmunisation
#
# [[12]]
# ...
