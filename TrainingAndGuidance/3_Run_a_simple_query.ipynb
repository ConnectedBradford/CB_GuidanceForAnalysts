# %%
#You will need to manually amend the target datasets for this script

library(bigrquery)

# Store the project ID
project_id = "yhcr-prd-phm-bia-core"

# Amend these to "point" at the datasets you want to query

targetdb1 <-'yhcr-prd-phm-bia-core.CB_FDM_MASTER'
targetdb1 <-gsub(' ','',targetdb1)
print (targetdb1)

targetdb2 <-'yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8'
targetdb2 <-gsub(' ','',targetdb2)
print (targetdb2)
# Out:
# [1] "yhcr-prd-phm-bia-core.CB_FDM_MASTER"
# [1] "yhcr-prd-phm-bia-core.CB_FDM_PrimaryCare_V8"

# %%
sql3 <-paste('select distinct a.person_id, 
a.ctv3code,
b.birth_datetime 
from ',targetdb2,'.tbl_srcode a
, ',targetdb1,'.person b 
where a.person_id = b.person_id 
and b.birth_datetime > "2020-05-01" 
order by a.person_id limit 1000;', sep = "")
#This runs it
tb3 <- bq_project_query(project_id, sql3)

#This loads  it into an R data frame
table <- bq_table_download(tb3)
#This displays it
table
# Out:
#      person_id ctv3code birth_datetime
# 1    5136897   XaQA3    2020-05-15
# 2    5136897   XacdW    2020-05-15
# 3    5136897   XE0pv    2020-05-15
# 4    5136897   XaIn9    2020-05-15
# 5    5136897   XaKc8    2020-05-15
# 6    5136897   Y1e8c    2020-05-15
# 7    5136897   XaQFt    2020-05-15
# 8    5136897   Ua0WM    2020-05-15
# 9    5136897   9NC3.    2020-05-15
# 10   5136897   XaPJj    2020-05-15
# 11   5136897   X76AT    2020-05-15
# 12   5136897   Y0bc4    2020-05-15
# 13   5136897   Ua1NC    2020-05-15
# 14   5136897   Y2a3c    2020-05-15
# 15   5136897   Y2ffe    2020-05-15
# 16   5136897   Xa7UB    2020-05-15
# 17   5136897   XaCaq    2020-05-15
# 18   5136897   XaZsn    2020-05-15
# 19   5136897   XaZLa    2020-05-15
# 20   5136897   9N25.    2020-05-15
# 21   5136897   9O5..    2020-05-15
# 22   5136897   YA953    2020-05-15
# 23   5136897   Ua0Ml    2020-05-15
# 24   5136897   Y1605    2020-05-15
# 25   5136897   YA000    2020-05-15
# 26   5136897   X76D5    2020-05-15
# 27   5136897   1921.    2020-05-15
# 28   5136897   6411.    2020-05-15
# 29   5136897   XE1SP    2020-05-15
# 30   5136897   YA911    2020-05-15
# ⋮    ⋮         ⋮        ⋮
# 971  5138896   XaZMS    2020-05-15
# 972  5138896   XaCaq    2020-05-15
# 973  5138896   YA040    2020-05-15
# 974  5138896   XaIgC    2020-05-15
# 975  5138896   XaJIx    2020-05-15
# 976  5138896   9NC5.    2020-05-15
# 977  5138896   Y1379    2020-05-15
# 978  5138896   Ua0Kb    2020-05-15
# 979  5138896   6422.    2020-05-15
# 980  5138896   XaIjW    2020-05-15
# 981  5138896   XaQA6    2020-05-15
# 982  5138896   XadG3    2020-05-15
# 983  5138896   Xa1kG    2020-05-15
# 984  5138896   68R2.    2020-05-15
# 985  5138896   Y1494    2020-05-15
# 986  5138896   Y0b77    2020-05-15
# 987  5138896   XaJJ4    2020-05-15
# 988  5138896   XaadS    2020-05-15
# 989  5138896   XaQiQ    2020-05-15
# 990  5138896   XaPwh    2020-05-15
# 991  5138896   XaZLa    2020-05-15
# 992  5138896   Y2948    2020-05-15
# 993  5138896   XaJJ0    2020-05-15
# 994  5138896   XaEDZ    2020-05-15
# 995  5138896   Xab9D    2020-05-15
# 996  5138896   XaW0d    2020-05-15
# 997  5138896   9N4F.    2020-05-15
# 998  5138896   XaLRi    2020-05-15
# 999  5138896   22A..    2020-05-15
# 1000 5138896   Y13e0    2020-05-15
